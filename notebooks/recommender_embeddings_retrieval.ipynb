# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import time
from typing import List
import pickle

import sys

sys.path.insert(0, "../src")  # needed for using the utils file in the notebook.
from utils import nutrition_facts_parser, sort_ingredients_alphabetically
from sentence_transformers import SentenceTransformer, util

from rich import inspect
from tqdm.notebook import tqdm

from tqdm.auto import tqdm

tqdm.pandas()

from transformers import AutoTokenizer, AutoModel
import torch

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## merging the title of the recipes back:

# %%
recipes_path = "../data/full_dataset.csv"
recipe_title_link = pd.read_csv(
    recipes_path,
    index_col=0,
    usecols=["title", "link"],
    dtype={
        "title": "string[pyarrow]",
        "link": "string[pyarrow]",
    },
)
recipe_title_link = recipe_title_link.query(
    " link.str.contains('allrecipes.com') "
)


data = pd.read_csv("all_recipes_data_w_nutrition_facts_unstructured.csv")
data_w_nutrition = data.query(" Nutrition_facts_unstructured.notnull() ")
print(data_w_nutrition.shape)

data_w_nutrition.head()
# Out:
# (41080, 3)
#                                                 link  \
# 0  www.allrecipes.com/recipe/241895/deconstructed...
# 1       www.allrecipes.com/recipe/20808/kettle-corn/
# 2  www.allrecipes.com/recipe/238733/pops-fabulous...
# 3  www.allrecipes.com/recipe/241254/chipotle-mang...
# 4  www.allrecipes.com/recipe/261696/basic-homemad...
#
#                                                  NER  \
# 0                  ['orange juice', 'jiggers vodka']
# 1  ['vegetable oil', 'white sugar', 'popcorn kern...
# 2  ['eggplants', 'green bell peppers', 'red bell ...
# 3  ['avocados', 'tomatoes', 'mango', 'cilantro', ...
# 4  ['milk', 'heavy whipping cream', 'white vinega...
#
#                         Nutrition_facts_unstructured
# 0  Nutrition Facts\nServings Per Recipe 1\nCalori...
# 1  Nutrition Facts\nServings Per Recipe 5\nCalori...
# 2  Nutrition Facts\nServings Per Recipe 10\nCalor...
# 3  Nutrition Facts\nServings Per Recipe 20\nCalor...
# 4  Nutrition Facts\nServings Per Recipe 4\nCalori...

# %%
data_w_nutrition = data_w_nutrition.merge(
    recipe_title_link.reset_index(),
    on="link",
    how="left",
    validate="1:1",
    copy=False,
)
print(data_w_nutrition.shape)
data_w_nutrition.head()
# Out:
# (41080, 4)
#                                                 link  \
# 0  www.allrecipes.com/recipe/241895/deconstructed...
# 1       www.allrecipes.com/recipe/20808/kettle-corn/
# 2  www.allrecipes.com/recipe/238733/pops-fabulous...
# 3  www.allrecipes.com/recipe/241254/chipotle-mang...
# 4  www.allrecipes.com/recipe/261696/basic-homemad...
#
#                                                  NER  \
# 0                  ['orange juice', 'jiggers vodka']
# 1  ['vegetable oil', 'white sugar', 'popcorn kern...
# 2  ['eggplants', 'green bell peppers', 'red bell ...
# 3  ['avocados', 'tomatoes', 'mango', 'cilantro', ...
# 4  ['milk', 'heavy whipping cream', 'white vinega...
#
#                         Nutrition_facts_unstructured  \
# 0  Nutrition Facts\nServings Per Recipe 1\nCalori...
# 1  Nutrition Facts\nServings Per Recipe 5\nCalori...
# 2  Nutrition Facts\nServings Per Recipe 10\nCalor...
# 3  Nutrition Facts\nServings Per Recipe 20\nCalor...
# 4  Nutrition Facts\nServings Per Recipe 4\nCalori...
#
#                                      title
# 0  Deconstructed Screwdriver (The Raw Egg)
# 1                              Kettle Corn
# 2                     Pop'S Fabulous Ajvar
# 3                 Chipotle-Mango Guacamole
# 4            Basic Homemade Ricotta Cheese

# %% [markdown]
# ## sort NER ingredients alphabetically:

# %%
data_w_nutrition.NER = data_w_nutrition.NER.apply(eval)

data_w_nutrition["sorted_NER"] = data_w_nutrition.NER.apply(
    sort_ingredients_alphabetically
)
data_w_nutrition.head()
# Out:
#                                                 link  \
# 0  www.allrecipes.com/recipe/241895/deconstructed...
# 1       www.allrecipes.com/recipe/20808/kettle-corn/
# 2  www.allrecipes.com/recipe/238733/pops-fabulous...
# 3  www.allrecipes.com/recipe/241254/chipotle-mang...
# 4  www.allrecipes.com/recipe/261696/basic-homemad...
#
#                                                  NER  \
# 0                      [orange juice, jiggers vodka]
# 1      [vegetable oil, white sugar, popcorn kernels]
# 2  [eggplants, green bell peppers, red bell peppe...
# 3  [avocados, tomatoes, mango, cilantro, red onio...
# 4  [milk, heavy whipping cream, white vinegar, salt]
#
#                         Nutrition_facts_unstructured  \
# 0  Nutrition Facts\nServings Per Recipe 1\nCalori...
# 1  Nutrition Facts\nServings Per Recipe 5\nCalori...
# 2  Nutrition Facts\nServings Per Recipe 10\nCalor...
# 3  Nutrition Facts\nServings Per Recipe 20\nCalor...
# 4  Nutrition Facts\nServings Per Recipe 4\nCalori...
#
#                                      title  \
# 0  Deconstructed Screwdriver (The Raw Egg)
# 1                              Kettle Corn
# 2                     Pop'S Fabulous Ajvar
# 3                 Chipotle-Mango Guacamole
# 4            Basic Homemade Ricotta Cheese
#
#                                           sorted_NER
# 0                      [jiggers vodka, orange juice]
# 1      [popcorn kernels, vegetable oil, white sugar]
# 2  [cooking spray, corn oil, eggplants, garlic, g...
# 3  [avocados, black pepper, cayenne pepper, cilan...
# 4  [heavy whipping cream, milk, salt, white vinegar]

# %% [markdown]
# ## Prepare for Sentence Transformer:
# - create singular "recipes" from each unique ingredient in the corpus --> each ingredient would have its own embedding as well.
# - get an embedding for each recipe based on the sorted NER ingredients.

# %%
all_ingredients = set(data_w_nutrition.NER.explode())
all_ingredients.remove(np.nan)
len(all_ingredients)
# Out:
# 9900

# %%
data_w_nutrition.columns
# Out:
# Index(['link', 'NER', 'Nutrition_facts_unstructured', 'title', 'sorted_NER'], dtype='object')

# %%
# create a 1 ingredient recipe so that we can get the embedding of each ingredient:

singular_ingredient_recipes_data = []

for ingredient in all_ingredients:
    singular_ingredient_recipes_data.append(
        {
            "link": np.nan,
            "NER": [ingredient],
            "Nutrition_facts_unstructured": "",
            "title": ingredient,
            "sorted_NER": [ingredient],
        }
    )
singular_ingredient_recipes = pd.DataFrame(
    data=singular_ingredient_recipes_data
)
print(singular_ingredient_recipes.shape)
singular_ingredient_recipes.head()
# Out:
# (9900, 5)
#    link                          NER  Nutrition_facts_unstructured  \
# 0   NaN  [coconut-almond milk blend]                           NaN
# 1   NaN                 [sushi rice]                           NaN
# 2   NaN                       [roux]                           NaN
# 3   NaN        [strawberry tomatoes]                           NaN
# 4   NaN    [Vegetable cooking spray]                           NaN
#
#                        title                   sorted_NER
# 0  coconut-almond milk blend  [coconut-almond milk blend]
# 1                 sushi rice                 [sushi rice]
# 2                       roux                       [roux]
# 3        strawberry tomatoes        [strawberry tomatoes]
# 4    Vegetable cooking spray    [Vegetable cooking spray]

# %%
data_w_nutrition = pd.concat([data_w_nutrition, singular_ingredient_recipes])
print(data_w_nutrition.shape)
# Out:
# (50980, 5)

# %%
data_w_nutrition.isnull().sum()
# Out:
# link                            9900
# NER                                0
# Nutrition_facts_unstructured    9900
# title                              0
# sorted_NER                         0
# dtype: int64

# %%
data_w_nutrition["sorted_joined_NER"] = data_w_nutrition.sorted_NER.str.join(
    " "
)

data_w_nutrition.sample()
# Out:
#                                                     link  \
# 37886  www.allrecipes.com/recipe/214204/roasted-pecan...
#
#                                                      NER  \
# 37886  [pecan pieces, butter, mushrooms, onion, fresh...
#
#                             Nutrition_facts_unstructured  \
# 37886  Nutrition Facts\nServings Per Recipe 4\nCalori...
#
#                                                    title  \
# 37886  Roasted Pecan Couscous With Sun Dried Tomatoes...
#
#                                               sorted_NER  \
# 37886  [butter, butter, fresh garlic, mushrooms, onio...
#
#                                        sorted_joined_NER
# 37886  butter butter fresh garlic mushrooms onion Par...

# %%
# max ingredient count in a recipe:
max_number_ingredients_per_recipe = data_w_nutrition.NER.apply(len).max()
max_number_ingredients_per_recipe
# Out:
# 37

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"


# Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[
        0
    ]  # First element of model_output contains all token embeddings
    input_mask_expanded = (
        attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    )
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask


def get_embedding(sentence: str):
    # Load AutoModel from huggingface model repository
    tokenizer = AutoTokenizer.from_pretrained(
        "sentence-transformers/all-MiniLM-L6-v2"
    )
    model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
    model.to(device=device)
    # Tokenize sentences
    encoded_input = tokenizer(
        sentence,
        padding=True,
        truncation=True,
        max_length=max_number_ingredients_per_recipe,
        return_tensors="pt",
    ).to(device=device)

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling. In this case, mean pooling
    sentence_embeddings = mean_pooling(
        model_output, encoded_input["attention_mask"]
    )
    return sentence_embeddings


# make sure we apply new indexing to retrieve the recipes later:
data_w_nutrition = data_w_nutrition.reset_index(drop=True)

# %%
data_w_nutrition.sorted_joined_NER.values[0]
# Out:
# 'jiggers vodka orange juice'

# %% [markdown]
# ## retrieving the embedding of each sorted list of ingredients and pickle-ing them with the data recipe index:

# %%
# with open('recipe_title_embeddings.pkl', "rb") as fIn:
#     recipe_title_embeddings = pickle.load(fIn)


# try:
#     for index in tqdm(
#         data_w_nutrition.index.values
#     ):
#         if str(index) not in recipe_title_embeddings.keys():
#             title_index = str(index)
#             # print(title_index)
#             ner = data_w_nutrition.iloc[index].sorted_joined_NER

#             recipe_title_embeddings[title_index] = get_embedding(sentence=ner)
#         # else:
#             # print("in dict already !")
# except (KeyboardInterrupt):
#     with open('recipe_title_embeddings.pkl', "wb") as fOut:
#         pickle.dump(recipe_title_embeddings, fOut, protocol=pickle.HIGHEST_PROTOCOL)


# with open('recipe_title_embeddings.pkl', "wb") as fOut:
#         pickle.dump(recipe_title_embeddings, fOut, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('recipe_title_embeddings_final.pkl', "wb") as fOut:
#         pickle.dump(recipe_title_embeddings, fOut, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## example cosine similarity - Sesame Seed Oil Hummus:

# %%
with open("recipe_title_embeddings_final.pkl", "rb") as fIn:
    recipe_title_embeddings = pickle.load(fIn)

data_w_nutrition.Nutrition_facts_unstructured.fillna("", inplace=True)

# %%
hummus_index = 300

hummus_recipe_embedding = recipe_title_embeddings[str(hummus_index)].to(
    device=device
)

# Sesame Seed Oil Hummus
data_w_nutrition.iloc[hummus_index].sorted_NER
# Out:
# ['chickpeas',
#  'garlic',
#  'ground black pepper',
#  'ground cumin',
#  'lemon juice',
#  'olive oil',
#  'salt',
#  'sesame seed oil',
#  'water']

# %%
corpus_embeddings.shape
# Out:
# torch.Size([50980, 384])

# %%
corpus_embeddings = torch.stack(list(recipe_title_embeddings.values()))
corpus_embeddings = util.normalize_embeddings(corpus_embeddings)
corpus_embeddings = torch.squeeze(corpus_embeddings, dim=1)

query_embedding = hummus_recipe_embedding.to(device)
query_embedding = torch.squeeze(query_embedding, dim=1)

hits = util.semantic_search(
    query_embedding, corpus_embeddings, score_function=util.dot_score
)

hits
# Out:
# [[{'corpus_id': 300, 'score': 50.34003829956055},
#   {'corpus_id': 26864, 'score': 45.16669464111328},
#   {'corpus_id': 7416, 'score': 43.72105407714844},
#   {'corpus_id': 591, 'score': 43.44393539428711},
#   {'corpus_id': 21131, 'score': 43.02387237548828},
#   {'corpus_id': 23173, 'score': 42.98396682739258},
#   {'corpus_id': 29324, 'score': 42.870750427246094},
#   {'corpus_id': 11703, 'score': 42.285736083984375},
#   {'corpus_id': 19812, 'score': 42.14165496826172},
#   {'corpus_id': 5500, 'score': 42.04046630859375}]]

# %%
data_w_nutrition.iloc[hits[0][1]["corpus_id"]]
# Out:
# link                            www.allrecipes.com/recipe/245692/fullas-roaste...
# NER                             [garlic, olive oil, chickpeas, tahini, olive o...
# Nutrition_facts_unstructured    Nutrition Facts\nServings Per Recipe 12\nCalor...
# title                                               Fulla'S Roasted Garlic Hummus
# sorted_NER                      [chickpeas, garlic, ground black pepper, groun...
# sorted_joined_NER               chickpeas garlic ground black pepper ground cu...
# Name: 26864, dtype: object

# %%
data_w_nutrition.query(" title.str.lower().str.contains('cake') ")
# Out:
#                                                     link  \
# 37     www.allrecipes.com/recipe/244635/grandma-sadie...
# 55     www.allrecipes.com/recipe/8327/chocolate-cherr...
# 82     www.allrecipes.com/recipe/246663/easy-ricotta-...
# 157    www.allrecipes.com/recipe/9525/christmas-nut-c...
# 174    www.allrecipes.com/recipe/220705/carlees-celeb...
# 196    www.allrecipes.com/recipe/162899/chocolate-haz...
# 197    www.allrecipes.com/recipe/7296/quick-black-for...
# 218    www.allrecipes.com/recipe/263853/fresh-nectari...
# 223    www.allrecipes.com/recipe/26024/cupcake-surprise/
# 241    www.allrecipes.com/recipe/260538/blini-russian...
# 245    www.allrecipes.com/recipe/261166/moist-german-...
# 251    www.allrecipes.com/recipe/241356/paleo-crab-ca...
# 259    www.allrecipes.com/recipe/8366/wedding-cake-ic...
# 279    www.allrecipes.com/recipe/152047/mango-ice-box...
# 282      www.allrecipes.com/recipe/8085/quick-fruitcake/
# 299     www.allrecipes.com/recipe/7995/oreo-cookie-cake/
# 332    www.allrecipes.com/recipe/185870/wacky-buckwhe...
# 339    www.allrecipes.com/recipe/238748/chocolate-ras...
# 367    www.allrecipes.com/recipe/8008/watergate-cake-...
# 381    www.allrecipes.com/recipe/25960/best-moist-cho...
# 384    www.allrecipes.com/recipe/217085/irish-pound-c...
# 386    www.allrecipes.com/recipe/259449/chocolate-mag...
# 394    www.allrecipes.com/recipe/23442/coconut-cream-...
# 410    www.allrecipes.com/recipe/246796/tres-leches-c...
# 418    www.allrecipes.com/recipe/67677/low-carb-choco...
# 437    www.allrecipes.com/recipe/24151/breakfast-saus...
# 465    www.allrecipes.com/recipe/261158/louisiana-chi...
# 475    www.allrecipes.com/recipe/16607/cheesecake-bro...
# 480    www.allrecipes.com/recipe/16209/apple-yogurt-p...
# 483    www.allrecipes.com/recipe/7712/fruit-cocktail-...
# 484    www.allrecipes.com/recipe/8216/burnt-sugar-cak...
# 504    www.allrecipes.com/recipe/231661/ricotta-easte...
# 518    www.allrecipes.com/recipe/7593/yellow-pound-cake/
# 519    www.allrecipes.com/recipe/234430/blueberry-cre...
# 530    www.allrecipes.com/recipe/191710/cornbread-pan...
# 563    www.allrecipes.com/recipe/264190/chocolate-pea...
# 571    www.allrecipes.com/recipe/8356/aargau-carrot-c...
# 580    www.allrecipes.com/recipe/262052/arepas-corn-g...
# 581    www.allrecipes.com/recipe/262216/russian-kefir...
# 583    www.allrecipes.com/recipe/7150/golden-cake-bat...
# 587    www.allrecipes.com/recipe/7423/mayonnaise-cake-i/
# 658    www.allrecipes.com/recipe/240173/sweet-potato-...
# 680    www.allrecipes.com/recipe/7625/whipped-cream-c...
# 710    www.allrecipes.com/recipe/8261/little-mickeys-...
# 716    www.allrecipes.com/recipe/8126/pumpkin-roll-cake/
# 718    www.allrecipes.com/recipe/256331/cinnamon-and-...
# 729    www.allrecipes.com/recipe/10934/italian-cheese...
# 739     www.allrecipes.com/recipe/22572/pumpkin-cake-ii/
# 746    www.allrecipes.com/recipe/7389/chocolate-chip-...
# 756    www.allrecipes.com/recipe/222870/moms-zucchini...
# 759    www.allrecipes.com/recipe/236568/james-westfal...
# 761        www.allrecipes.com/recipe/7872/wacky-cake-iv/
# 781    www.allrecipes.com/recipe/255235/sweet-potato-...
# 804    www.allrecipes.com/recipe/246726/milk-chocolat...
# 826    www.allrecipes.com/recipe/266182/low-carb-pump...
# 840    www.allrecipes.com/recipe/220471/irish-apple-c...
# 845    www.allrecipes.com/recipe/49066/the-best-unbak...
# 851    www.allrecipes.com/recipe/8106/easy-rich-choco...
# 868    www.allrecipes.com/recipe/139953/trini-mango-c...
# 883    www.allrecipes.com/recipe/7739/coconut-chocola...
# 901    www.allrecipes.com/recipe/8402/aunt-dee-dees-a...
# 902    www.allrecipes.com/recipe/260964/vanilla-caram...
# 903    www.allrecipes.com/recipe/136566/georgias-tenn...
# 912    www.allrecipes.com/recipe/244661/one-bowl-vani...
# 914    www.allrecipes.com/recipe/238327/frosted-pink-...
# 930    www.allrecipes.com/recipe/236940/bacon-pancake...
# 939    www.allrecipes.com/recipe/233074/grandads-panc...
# 946    www.allrecipes.com/recipe/7302/the-best-chocol...
# 951    www.allrecipes.com/recipe/89037/true-maryland-...
# 994       www.allrecipes.com/recipe/231087/doberge-cake/
# 1004   www.allrecipes.com/recipe/22281/black-bottom-c...
# 1010   www.allrecipes.com/recipe/18161/coco-cola-cake...
# 1016     www.allrecipes.com/recipe/20714/cheesecake-dip/
# 1043   www.allrecipes.com/recipe/222228/brownie-cupca...
# 1049   www.allrecipes.com/recipe/16251/valentine-hear...
# 1050   www.allrecipes.com/recipe/220329/make-ahead-so...
# 1057   www.allrecipes.com/recipe/260685/easy-german-a...
# 1075      www.allrecipes.com/recipe/7254/carrot-cake-ii/
# 1098   www.allrecipes.com/recipe/8232/chocolate-puddi...
# 1105   www.allrecipes.com/recipe/257022/honey-bun-cak...
# 1118   www.allrecipes.com/recipe/8206/peppermint-chif...
# 1129   www.allrecipes.com/recipe/11642/old-fashioned-...
# 1157   www.allrecipes.com/recipe/230070/banana-butter...
# 1181   www.allrecipes.com/recipe/260785/mexican-choco...
# 1215         www.allrecipes.com/recipe/18977/zebra-cake/
# 1220   www.allrecipes.com/recipe/240267/olive-oil-lem...
# 1233   www.allrecipes.com/recipe/7946/sour-cream-bana...
# 1255   www.allrecipes.com/recipe/10111/old-fashioned-...
# 1259   www.allrecipes.com/recipe/247382/bolo-de-banan...
# 1276    www.allrecipes.com/recipe/15145/cream-tea-cakes/
# 1280   www.allrecipes.com/recipe/205632/quick-camping...
# 1293    www.allrecipes.com/recipe/8122/caterpillar-cake/
# 1305   www.allrecipes.com/recipe/8378/strawberries-an...
# 1306   www.allrecipes.com/recipe/239950/sweet-pumpkin...
# 1313   www.allrecipes.com/recipe/7541/mini-cinnamon-c...
# 1329          www.allrecipes.com/recipe/8267/amish-cake/
# 1345   www.allrecipes.com/recipe/234679/pumpkin-spice...
# 1350   www.allrecipes.com/recipe/269034/chewy-coconut...
# 1394   www.allrecipes.com/recipe/11794/pastira-macaro...
# 1399   www.allrecipes.com/recipe/8102/sock-it-to-me-c...
# 1408   www.allrecipes.com/recipe/269360/whole-wheat-a...
# 1412        www.allrecipes.com/recipe/132575/sage-cakes/
# 1435   www.allrecipes.com/recipe/269516/eggnog-poke-c...
# 1438   www.allrecipes.com/recipe/256337/coconut-delig...
# 1452   www.allrecipes.com/recipe/213813/steamed-panda...
# 1475   www.allrecipes.com/recipe/220153/broken-glass-...
# 1478   www.allrecipes.com/recipe/7618/very-special-to...
# 1504   www.allrecipes.com/recipe/216466/breakfast-ban...
# 1511   www.allrecipes.com/recipe/240469/isaacs-carrot...
# 1556   www.allrecipes.com/recipe/258018/pumpkin-crunc...
# 1563   www.allrecipes.com/recipe/246027/red-velvet-ca...
# 1607   www.allrecipes.com/recipe/229930/turkey-spotli...
# 1625   www.allrecipes.com/recipe/241685/easter-bunny-...
# 1626   www.allrecipes.com/recipe/236755/saskatoon-ber...
# 1630   www.allrecipes.com/recipe/66310/maple-pumpkin-...
# 1639   www.allrecipes.com/recipe/245823/portuguese-co...
# 1647   www.allrecipes.com/recipe/263945/creme-brulee-...
# 1664   www.allrecipes.com/recipe/7708/black-forest-du...
# 1666   www.allrecipes.com/recipe/83373/mediterranean-...
# 1699   www.allrecipes.com/recipe/241161/coconut-flour...
# 1701      www.allrecipes.com/recipe/26023/crumb-cake-ii/
# 1709   www.allrecipes.com/recipe/223600/raspberry-cre...
# 1721   www.allrecipes.com/recipe/7490/eggless-milkles...
# 1730   www.allrecipes.com/recipe/26034/oatmeal-pralin...
# 1737   www.allrecipes.com/recipe/7996/fruit-cocktail-...
# 1748   www.allrecipes.com/recipe/235831/pineapple-ups...
# 1749   www.allrecipes.com/recipe/7722/buttermilk-poun...
# 1761   www.allrecipes.com/recipe/260504/vegan-banana-...
# 1765   www.allrecipes.com/recipe/234730/boonas-butter...
# 1782   www.allrecipes.com/recipe/246515/delicious-low...
# 1787   www.allrecipes.com/recipe/7867/moms-chocolate-...
# 1802   www.allrecipes.com/recipe/264044/very-berry-su...
# 1817      www.allrecipes.com/recipe/8006/banana-cake-iv/
# 1831   www.allrecipes.com/recipe/26015/cold-oven-poun...
# 1833   www.allrecipes.com/recipe/262703/apple-bacon-c...
# 1844   www.allrecipes.com/recipe/257191/rich-and-gooe...
# 1849   www.allrecipes.com/recipe/233358/tiffanys-pump...
# 1850   www.allrecipes.com/recipe/25584/german-apple-p...
# 1852   www.allrecipes.com/recipe/8033/apple-cake-and-...
# 1854   www.allrecipes.com/recipe/132633/kims-eggnog-c...
# 1866   www.allrecipes.com/recipe/7661/chocolate-icebo...
# 1923   www.allrecipes.com/recipe/80677/worlds-best-ve...
# 1962   www.allrecipes.com/recipe/212429/red-velvet-cu...
# 1966   www.allrecipes.com/recipe/33106/delicious-panc...
# 2001   www.allrecipes.com/recipe/254400/lemon-lavende...
# 2003   www.allrecipes.com/recipe/216723/spicy-carrot-...
# 2009   www.allrecipes.com/recipe/229625/camilles-butt...
# 2012   www.allrecipes.com/recipe/7875/pudding-poke-cake/
# 2025   www.allrecipes.com/recipe/218101/suzyqs-elegan...
# 2049   www.allrecipes.com/recipe/233423/raspberry-sho...
# 2062         www.allrecipes.com/recipe/7827/poke-cake-i/
# 2100   www.allrecipes.com/recipe/20309/rainbow-sherbe...
# 2101   www.allrecipes.com/recipe/142016/perfumed-coco...
# 2106   www.allrecipes.com/recipe/7453/chocolate-caram...
# 2107   www.allrecipes.com/recipe/256398/spongy-japane...
# 2108   www.allrecipes.com/recipe/79312/gingerbread-pe...
# 2139   www.allrecipes.com/recipe/143180/white-chococo...
# 2142     www.allrecipes.com/recipe/7702/lemon-gold-cake/
# 2162   www.allrecipes.com/recipe/220616/kicked-up-pot...
# 2169   www.allrecipes.com/recipe/7421/better-than-sex...
# 2171   www.allrecipes.com/recipe/8434/nannies-hot-mil...
# 2173   www.allrecipes.com/recipe/7333/strawberry-cake-i/
# 2205   www.allrecipes.com/recipe/85305/cheater-pancak...
# 2220   www.allrecipes.com/recipe/257013/lemon-cinnamo...
# 2234   www.allrecipes.com/recipe/126857/caribbean-gri...
# 2236   www.allrecipes.com/recipe/228654/quick-oatmeal...
# 2248   www.allrecipes.com/recipe/33209/potato-pancake...
# 2321   www.allrecipes.com/recipe/24196/pumpkin-layer-...
# 2322   www.allrecipes.com/recipe/49953/chocolate-bana...
# 2408   www.allrecipes.com/recipe/7520/poppy-seed-cake-i/
# 2419   www.allrecipes.com/recipe/7357/chocolate-mint-...
# 2423   www.allrecipes.com/recipe/239583/tuxedo-cheese...
# 2433   www.allrecipes.com/recipe/242131/zesty-orange-...
# 2440   www.allrecipes.com/recipe/7672/very-moist-gumd...
# 2446   www.allrecipes.com/recipe/268008/cherry-center...
# 2450   www.allrecipes.com/recipe/260257/minty-mini-ch...
# 2508   www.allrecipes.com/recipe/15027/overnight-rais...
# 2539   www.allrecipes.com/recipe/8281/pineapple-angel...
# 2554         www.allrecipes.com/recipe/8047/orange-cake/
# 2564   www.allrecipes.com/recipe/264661/vanilla-cupca...
# 2591   www.allrecipes.com/recipe/12510/apple-danish-c...
# 2592   www.allrecipes.com/recipe/259921/blueberry-ups...
# 2617   www.allrecipes.com/recipe/244201/chef-johns-cl...
# 2651     www.allrecipes.com/recipe/178374/cabbage-cakes/
# 2653   www.allrecipes.com/recipe/102426/pumpkin-pie-c...
# 2679   www.allrecipes.com/recipe/26005/chocolate-zucc...
# 2680   www.allrecipes.com/recipe/254303/whole-grain-p...
# 2683   www.allrecipes.com/recipe/7667/chocolate-mocha...
# 2686   www.allrecipes.com/recipe/17549/fabulous-orang...
# 2689   www.allrecipes.com/recipe/262511/rose-pavlova-...
# 2694            www.allrecipes.com/recipe/8056/pancakes/
# 2695      www.allrecipes.com/recipe/21855/poke-cake-iii/
# 2703   www.allrecipes.com/recipe/14984/amazing-apple-...
# 2710   www.allrecipes.com/recipe/212973/mamon-sponge-...
# 2720   www.allrecipes.com/recipe/17234/pig-picking-ca...
# 2730   www.allrecipes.com/recipe/240394/titis-cranber...
# 2743   www.allrecipes.com/recipe/254295/mini-pumpkin-...
# 2745   www.allrecipes.com/recipe/17642/glazed-lemon-s...
# 2746   www.allrecipes.com/recipe/83814/peanut-butter-...
# 2752   www.allrecipes.com/recipe/236906/gluten-free-p...
# 2762   www.allrecipes.com/recipe/267709/cake-pops-wit...
# 2772   www.allrecipes.com/recipe/242048/rice-flour-pa...
# 2774      www.allrecipes.com/recipe/18029/mocha-cake-iv/
# 2778   www.allrecipes.com/recipe/7491/fabulously-swee...
# 2782   www.allrecipes.com/recipe/246032/creamsicle-pa...
# 2792   www.allrecipes.com/recipe/235074/super-easy-ha...
# 2800   www.allrecipes.com/recipe/7819/apricot-brandy-...
# 2824   www.allrecipes.com/recipe/246370/aunt-berts-fr...
# 2833   www.allrecipes.com/recipe/263043/mini-samoa-bu...
# 2846   www.allrecipes.com/recipe/213341/perfect-st-pa...
# 2872   www.allrecipes.com/recipe/166609/toasted-cocon...
# 2897   www.allrecipes.com/recipe/222846/fresh-cherry-...
# 2910   www.allrecipes.com/recipe/7289/texas-sheet-cak...
# 2913   www.allrecipes.com/recipe/260367/keto-friendly...
# 2938   www.allrecipes.com/recipe/12129/easy-cheesecak...
# 2946     www.allrecipes.com/recipe/208589/snowball-cake/
# 2952   www.allrecipes.com/recipe/233951/peanut-butter...
# 3007      www.allrecipes.com/recipe/7382/ice-box-cake-i/
# 3027   www.allrecipes.com/recipe/260551/arvidson-swed...
# 3034    www.allrecipes.com/recipe/8235/coconut-cake-iii/
# 3041   www.allrecipes.com/recipe/235148/easy-butterfi...
# 3048   www.allrecipes.com/recipe/239320/cake-mix-pump...
# 3056   www.allrecipes.com/recipe/255406/apple-butter-...
# 3115   www.allrecipes.com/recipe/18180/microwave-miss...
# 3132   www.allrecipes.com/recipe/229542/carrot-cake-w...
# 3136   www.allrecipes.com/recipe/7982/cherries-in-the...
# 3140      www.allrecipes.com/recipe/9278/moms-fruitcake/
# 3141   www.allrecipes.com/recipe/246725/fudge-marble-...
# 3148   www.allrecipes.com/recipe/232158/simple-banana...
# 3170   www.allrecipes.com/recipe/213000/palitaw-sweet...
# 3186   www.allrecipes.com/recipe/237706/mounds-bar-cake/
# 3207      www.allrecipes.com/recipe/231782/soy-pancakes/
# 3219   www.allrecipes.com/recipe/7659/deep-dark-choco...
# 3263   www.allrecipes.com/recipe/260774/halloween-cyc...
# 3293   www.allrecipes.com/recipe/17586/waldorf-astori...
# 3333   www.allrecipes.com/recipe/222132/healthier-goo...
# 3354   www.allrecipes.com/recipe/221383/apfelkuchen-a...
# 3371   www.allrecipes.com/recipe/235525/grandmas-soul...
# 3380   www.allrecipes.com/recipe/8026/sugarless-fruit...
# 3433      www.allrecipes.com/recipe/9265/christmas-cake/
# 3450    www.allrecipes.com/recipe/8330/swedish-nut-cake/
# 3456   www.allrecipes.com/recipe/8444/black-forest-ca...
# 3469   www.allrecipes.com/recipe/26002/chocolate-shee...
# 3486   www.allrecipes.com/recipe/263961/vegan-protein...
# 3507   www.allrecipes.com/recipe/261167/alsatian-appl...
# 3529      www.allrecipes.com/recipe/8410/yum-yum-cake-i/
# 3532   www.allrecipes.com/recipe/8178/date-nut-mayonn...
# 3537   www.allrecipes.com/recipe/19081/sayuris-three-...
# 3556   www.allrecipes.com/recipe/21266/old-fashioned-...
# 3557        www.allrecipes.com/recipe/7682/cassata-cake/
# 3572   www.allrecipes.com/recipe/8320/sour-cream-choc...
# 3576   www.allrecipes.com/recipe/257189/wicked-yellow...
# 3580   www.allrecipes.com/recipe/8098/french-chocolat...
# 3590   www.allrecipes.com/recipe/263943/japanese-cott...
# 3594   www.allrecipes.com/recipe/234994/thanksgiving-...
# 3596   www.allrecipes.com/recipe/7869/neiman-marcus-c...
# 3616   www.allrecipes.com/recipe/50936/apple-puff-pan...
# 3634   www.allrecipes.com/recipe/24996/fluffy-two-ste...
# 3648   www.allrecipes.com/recipe/17176/swedish-pancakes/
# 3662   www.allrecipes.com/recipe/260056/flourless-cho...
# 3674   www.allrecipes.com/recipe/15823/mini-cheesecakes/
# 3687   www.allrecipes.com/recipe/255847/apple-taffy-c...
# 3694   www.allrecipes.com/recipe/55390/apple-cider-pa...
# 3697   www.allrecipes.com/recipe/260329/crunchy-sweet...
# 3698   www.allrecipes.com/recipe/7248/peanut-butter-c...
# 3708           www.allrecipes.com/recipe/7792/plum-cake/
# 3734   www.allrecipes.com/recipe/8129/chocolate-earth...
# 3735   www.allrecipes.com/recipe/244453/canadian-flag...
# 3747   www.allrecipes.com/recipe/270198/chocolate-cak...
# 3772    www.allrecipes.com/recipe/7500/spanish-bar-cake/
# 3791   www.allrecipes.com/recipe/7937/very-berry-chee...
# 3793   www.allrecipes.com/recipe/8312/chocolate-puddi...
# 3794   www.allrecipes.com/recipe/139340/baked-marylan...
# 3810   www.allrecipes.com/recipe/264066/fanouropita-v...
# 3812   www.allrecipes.com/recipe/26049/pineapple-shee...
# 3815   www.allrecipes.com/recipe/257556/raspberry-che...
# 3823   www.allrecipes.com/recipe/44653/steamed-sponge...
# 3842      www.allrecipes.com/recipe/17947/carrot-cake-x/
# 3854   www.allrecipes.com/recipe/217100/dianas-guinne...
# 3873   www.allrecipes.com/recipe/22264/banana-layer-c...
# 3892   www.allrecipes.com/recipe/231889/crab-cakes-wi...
# 3922   www.allrecipes.com/recipe/263788/zucchini-waln...
# 3946   www.allrecipes.com/recipe/8068/heritage-jam-cake/
# 3953   www.allrecipes.com/recipe/260263/savory-breakf...
# 3955   www.allrecipes.com/recipe/256993/chocolate-and...
# 3958   www.allrecipes.com/recipe/8477/old-fashioned-r...
# 3970   www.allrecipes.com/recipe/7267/best-cheesecake...
# 3975   www.allrecipes.com/recipe/11515/mocha-mint-che...
# 3978   www.allrecipes.com/recipe/263113/keto-ny-chees...
# 3991   www.allrecipes.com/recipe/264191/morgans-reduc...
# 3994   www.allrecipes.com/recipe/7352/our-favorite-ch...
# 3998   www.allrecipes.com/recipe/15518/eggless-butter...
# 4015   www.allrecipes.com/recipe/25574/easy-cheese-cake/
# 4019   www.allrecipes.com/recipe/25588/peach-cobbler-...
# 4024   www.allrecipes.com/recipe/221121/zucchini-coco...
# 4031   www.allrecipes.com/recipe/7653/orange-pecan-cake/
# 4035   www.allrecipes.com/recipe/267630/keto-cheeseca...
# 4059    www.allrecipes.com/recipe/18135/easy-party-cake/
# 4106   www.allrecipes.com/recipe/263962/vegan-protein...
# 4115   www.allrecipes.com/recipe/263637/baker-bens-ve...
# 4116   www.allrecipes.com/recipe/26320/chocolate-love...
# 4123   www.allrecipes.com/recipe/260886/delicious-car...
# 4134   www.allrecipes.com/recipe/233342/blueberry-mys...
# 4142   www.allrecipes.com/recipe/260550/swedish-panca...
# 4161   www.allrecipes.com/recipe/8037/no-guilt-cheese...
# 4167   www.allrecipes.com/recipe/7976/eggnog-cheesecake/
# 4182   www.allrecipes.com/recipe/246454/ancient-honey...
# 4189   www.allrecipes.com/recipe/260651/mexican-tres-...
# 4201   www.allrecipes.com/recipe/241592/rainbow-veggi...
# 4230   www.allrecipes.com/recipe/7899/banana-oatmeal-...
# 4240       www.allrecipes.com/recipe/92359/bat-cupcakes/
# 4259   www.allrecipes.com/recipe/256480/caramel-panca...
# 4279   www.allrecipes.com/recipe/24967/autumn-apple-b...
# 4286   www.allrecipes.com/recipe/260093/spiced-banana...
# 4341   www.allrecipes.com/recipe/7925/blue-cheese-che...
# 4346   www.allrecipes.com/recipe/216732/strawberry-ch...
# 4351   www.allrecipes.com/recipe/100496/honey-cupcake...
# 4352   www.allrecipes.com/recipe/235793/how-to-make-t...
# 4370   www.allrecipes.com/recipe/268572/ghirardelli-i...
# 4451     www.allrecipes.com/recipe/7457/sauerkraut-cake/
# 4456   www.allrecipes.com/recipe/19004/chi-chis-corn-...
# 4483   www.allrecipes.com/recipe/234446/salmonberry-c...
# 4499   www.allrecipes.com/recipe/130800/holiday-pumpk...
# 4518   www.allrecipes.com/recipe/220800/mascarpone-st...
# 4524   www.allrecipes.com/recipe/221100/byrons-delici...
# 4532    www.allrecipes.com/recipe/7581/anniversary-cake/
# 4535   www.allrecipes.com/recipe/15541/black-walnut-c...
# 4564   www.allrecipes.com/recipe/88185/sopapilla-chee...
# 4566   www.allrecipes.com/recipe/246907/glazed-bluebe...
# 4574   www.allrecipes.com/recipe/254412/coconut-greek...
# 4587   www.allrecipes.com/recipe/256921/chocolate-car...
# 4593   www.allrecipes.com/recipe/220798/justins-frost...
# 4595   www.allrecipes.com/recipe/219010/honey-cake-wi...
# 4607   www.allrecipes.com/recipe/7760/apple-carrot-or...
# 4621   www.allrecipes.com/recipe/230755/strawberry-ch...
# 4627   www.allrecipes.com/recipe/264153/chocolate-bee...
# 4637   www.allrecipes.com/recipe/236213/amaranth-panc...
# 4640   www.allrecipes.com/recipe/221275/banana-berry-...
# 4643   www.allrecipes.com/recipe/8252/chocolate-angel...
# 4667   www.allrecipes.com/recipe/74837/sugar-free-blu...
# 4690   www.allrecipes.com/recipe/232604/fabulous-carr...
# 4707   www.allrecipes.com/recipe/228477/rice-cooker-m...
# 4736    www.allrecipes.com/recipe/8011/fudge-layer-cake/
# 4762   www.allrecipes.com/recipe/233353/georgia-cornb...
# 4763   www.allrecipes.com/recipe/52581/easy-swedish-p...
# 4770   www.allrecipes.com/recipe/231865/red-velvet-ch...
# 4783   www.allrecipes.com/recipe/228735/caramel-apple...
# 4785      www.allrecipes.com/recipe/17487/oven-pancakes/
# 4789   www.allrecipes.com/recipe/263944/cotton-cheese...
# 4801   www.allrecipes.com/recipe/25580/fruit-cocktail...
# 4829   www.allrecipes.com/recipe/220809/boston-creme-...
# 4830   www.allrecipes.com/recipe/229264/loaded-mashed...
# 4838   www.allrecipes.com/recipe/218576/avons-end-of-...
# 4839   www.allrecipes.com/recipe/143162/stars-and-str...
# 4849   www.allrecipes.com/recipe/17660/orange-kiss-me...
# 4857   www.allrecipes.com/recipe/107221/grams-poppy-s...
# 4895   www.allrecipes.com/recipe/185675/leftover-turk...
# 4896   www.allrecipes.com/recipe/8009/eggless-chocola...
# 4907   www.allrecipes.com/recipe/24991/zucchini-choco...
# 4917   www.allrecipes.com/recipe/9499/delicious-whole...
# 4929   www.allrecipes.com/recipe/245000/tres-leches-c...
# 4957   www.allrecipes.com/recipe/268787/cinnamon-and-...
# 4958   www.allrecipes.com/recipe/179716/caramel-apple...
# 4972   www.allrecipes.com/recipe/17623/dark-and-moist...
# 4996   www.allrecipes.com/recipe/238228/simple-salmon...
# 4997   www.allrecipes.com/recipe/7454/caramel-nougat-...
# 5003   www.allrecipes.com/recipe/260887/easy-caramel-...
# 5039   www.allrecipes.com/recipe/7845/raspberry-icebo...
# 5044   www.allrecipes.com/recipe/260884/three-layer-c...
# 5062   www.allrecipes.com/recipe/74029/nova-scotia-bl...
# 5072   www.allrecipes.com/recipe/256115/pina-colada-c...
# 5086   www.allrecipes.com/recipe/8450/moms-pineapple-...
# 5117   www.allrecipes.com/recipe/263790/korean-rice-c...
# 5136   www.allrecipes.com/recipe/57606/grain-and-nut-...
# 5138     www.allrecipes.com/recipe/8291/carrot-cake-vii/
# 5149   www.allrecipes.com/recipe/17851/pineapple-cher...
# 5156   www.allrecipes.com/recipe/148775/absolute-best...
# 5165   www.allrecipes.com/recipe/77375/two-ingredient...
# 5175   www.allrecipes.com/recipe/244673/strawberry-sh...
# 5183    www.allrecipes.com/recipe/263727/vegan-mug-cake/
# 5213    www.allrecipes.com/recipe/259804/cake-flour-mix/
# 5222   www.allrecipes.com/recipe/232349/filled-rhubar...
# 5242   www.allrecipes.com/recipe/19087/cappuccino-cak...
# 5254   www.allrecipes.com/recipe/237715/low-carb-tuna...
# 5255    www.allrecipes.com/recipe/25598/lite-cheesecake/
# 5268   www.allrecipes.com/recipe/260679/easy-coconut-...
# 5278   www.allrecipes.com/recipe/7877/yellow-angel-fo...
# 5297     www.allrecipes.com/recipe/7838/ice-box-cake-ii/
# 5299   www.allrecipes.com/recipe/7671/sourdough-choco...
# 5314   www.allrecipes.com/recipe/19114/barbaras-golde...
# 5320   www.allrecipes.com/recipe/36168/louisiana-swee...
# 5334   www.allrecipes.com/recipe/25601/mango-and-mixe...
# 5340   www.allrecipes.com/recipe/21297/easy-salmon-ca...
# 5341   www.allrecipes.com/recipe/92424/fluffy-pancake...
# 5348   www.allrecipes.com/recipe/247210/butterfinger-...
# 5349   www.allrecipes.com/recipe/23663/western-pound-...
# 5352   www.allrecipes.com/recipe/244777/apple-pie-cak...
# 5384   www.allrecipes.com/recipe/7614/lane-cake-filling/
# 5407   www.allrecipes.com/recipe/255846/pumpkin-upsid...
# 5443   www.allrecipes.com/recipe/218095/low-carb-panc...
# 5447     www.allrecipes.com/recipe/21192/funnel-cakes-v/
# 5510   www.allrecipes.com/recipe/15392/wellesley-fudg...
# 5515   www.allrecipes.com/recipe/241169/orange-pancakes/
# 5523   www.allrecipes.com/recipe/263959/fluffy-japane...
# 5524   www.allrecipes.com/recipe/136471/gluten-free-c...
# 5547   www.allrecipes.com/recipe/75645/minty-middle-c...
# 5549        www.allrecipes.com/recipe/7829/poke-cake-ii/
# 5558   www.allrecipes.com/recipe/7700/autumn-cheesecake/
# 5563   www.allrecipes.com/recipe/18049/grandmas-fresh...
# 5567   www.allrecipes.com/recipe/8400/special-frosted...
# 5594   www.allrecipes.com/recipe/244374/easy-chocolat...
# 5608   www.allrecipes.com/recipe/8390/tunnel-of-fudge...
# 5612   www.allrecipes.com/recipe/8349/yellow-chess-cake/
# 5617   www.allrecipes.com/recipe/8277/mmmmmm-chocolat...
# 5640   www.allrecipes.com/recipe/239711/best-ever-pum...
# 5665   www.allrecipes.com/recipe/8474/orange-date-nut...
# 5696   www.allrecipes.com/recipe/239284/german-pear-p...
# 5703   www.allrecipes.com/recipe/7546/cheesecake-supr...
# 5708   www.allrecipes.com/recipe/66708/chocolate-pear...
# 5735      www.allrecipes.com/recipe/260883/caramel-cake/
# 5742   www.allrecipes.com/recipe/8342/rhubarb-upside-...
# 5746        www.allrecipes.com/recipe/8100/wacky-cake-v/
# 5752   www.allrecipes.com/recipe/7957/richest-ever-ch...
# 5772   www.allrecipes.com/recipe/132659/traditional-c...
# 5797        www.allrecipes.com/recipe/7786/mocha-cake-i/
# 5800   www.allrecipes.com/recipe/239794/oreo-mini-che...
# 5802   www.allrecipes.com/recipe/7577/lemon-sponge-ca...
# 5829   www.allrecipes.com/recipe/87483/authentic-germ...
# 5847    www.allrecipes.com/recipe/8012/apple-stack-cake/
# 5854   www.allrecipes.com/recipe/257773/minty-fresh-d...
# 5856     www.allrecipes.com/recipe/26057/pound-cake-iii/
# 5882   www.allrecipes.com/recipe/264824/paleo-pancake...
# 5907   www.allrecipes.com/recipe/219684/simple-christ...
# 5911    www.allrecipes.com/recipe/53654/the-wessel-cake/
# 5946   www.allrecipes.com/recipe/256533/british-butte...
# 5966   www.allrecipes.com/recipe/245743/red-devils-fo...
# 5973    www.allrecipes.com/recipe/8298/pecan-pie-cake-i/
# 5976   www.allrecipes.com/recipe/268045/vegan-carrot-...
# 5977   www.allrecipes.com/recipe/21717/streusel-apple...
# 6015   www.allrecipes.com/recipe/7300/botercake-butte...
# 6036   www.allrecipes.com/recipe/214974/buttermilk-ma...
# 6051   www.allrecipes.com/recipe/17427/irish-potato-c...
# 6074    www.allrecipes.com/recipe/64021/thai-fish-cakes/
# 6079   www.allrecipes.com/recipe/8289/poor-mans-cake-...
# 6080   www.allrecipes.com/recipe/20525/blue-cheese-cake/
# 6093   www.allrecipes.com/recipe/231416/apple-coffee-...
# 6106   www.allrecipes.com/recipe/7263/boiled-raisin-c...
# 6133   www.allrecipes.com/recipe/255982/elegant-cake-...
# 6136   www.allrecipes.com/recipe/228627/paleo-pumpkin...
# 6166   www.allrecipes.com/recipe/8344/banana-split-ca...
# 6172   www.allrecipes.com/recipe/258853/yummy-easy-ch...
# 6182   www.allrecipes.com/recipe/223597/old-fashioned...
# 6198   www.allrecipes.com/recipe/257241/hornets-nest-...
# 6211   www.allrecipes.com/recipe/261184/lego-sheet-cake/
# 6218     www.allrecipes.com/recipe/7276/easy-lemon-cake/
# 6221   www.allrecipes.com/recipe/217903/firecracker-c...
# 6244   www.allrecipes.com/recipe/221258/strawberry-ch...
# 6247   www.allrecipes.com/recipe/246378/melted-ice-cr...
# 6258   www.allrecipes.com/recipe/259795/michelles-cak...
# 6260   www.allrecipes.com/recipe/256285/easy-cranberr...
# 6267   www.allrecipes.com/recipe/258756/pistachio-nut...
# 6276      www.allrecipes.com/recipe/7285/microwave-cake/
# 6277   www.allrecipes.com/recipe/247383/bolo-de-fuba-...
# 6291   www.allrecipes.com/recipe/26037/peaches-and-cr...
# 6298   www.allrecipes.com/recipe/17382/cake-mix-cooki...
# 6319         www.allrecipes.com/recipe/7679/nutmeg-cake/
# 6340   www.allrecipes.com/recipe/27234/applesauce-rai...
# 6353   www.allrecipes.com/recipe/17817/banana-cake-viii/
# 6358   www.allrecipes.com/recipe/242115/carrot-cake-m...
# 6365   www.allrecipes.com/recipe/8014/simple-n-delici...
# 6384   www.allrecipes.com/recipe/17436/rich-chocolate...
# 6419   www.allrecipes.com/recipe/218004/petras-strawb...
# 6437   www.allrecipes.com/recipe/21007/moms-prize-win...
# 6461   www.allrecipes.com/recipe/237431/raspberry-coc...
# 6485   www.allrecipes.com/recipe/240890/strawberry-sh...
# 6510   www.allrecipes.com/recipe/18150/holiday-fudge-...
# 6530   www.allrecipes.com/recipe/239975/white-chocola...
# 6537   www.allrecipes.com/recipe/232412/delicious-app...
# 6541   www.allrecipes.com/recipe/222737/pumpkin-chees...
# 6549         www.allrecipes.com/recipe/8016/dump-cake-v/
# 6555    www.allrecipes.com/recipe/7313/brown-sugar-cake/
# 6584   www.allrecipes.com/recipe/23661/pumpkin-spice-...
# 6601   www.allrecipes.com/recipe/246063/funfetti-cake...
# 6608   www.allrecipes.com/recipe/7690/cherry-almond-c...
# 6646   www.allrecipes.com/recipe/214727/five-minute-l...
# 6651   www.allrecipes.com/recipe/228672/zucchini-nut-...
# 6672   www.allrecipes.com/recipe/220142/fluffy-swedis...
# 6685   www.allrecipes.com/recipe/255880/carrot-cake-e...
# 6702   www.allrecipes.com/recipe/245178/christmas-tre...
# 6706   www.allrecipes.com/recipe/257016/kropsua-finni...
# 6710   www.allrecipes.com/recipe/8127/new-duchess-spi...
# 6711   www.allrecipes.com/recipe/27491/aunt-annes-cof...
# 6719   www.allrecipes.com/recipe/17985/bundt-cake-fru...
# 6722   www.allrecipes.com/recipe/232935/fudge-truffle...
# 6725   www.allrecipes.com/recipe/190857/leftover-panc...
# 6737   www.allrecipes.com/recipe/212454/vanilla-sesam...
# 6745   www.allrecipes.com/recipe/72211/vegetable-panc...
# 6755   www.allrecipes.com/recipe/7696/berthas-big-bou...
# 6818   www.allrecipes.com/recipe/24973/easy-platz-cof...
# 6828   www.allrecipes.com/recipe/220938/moms-apricot-...
# 6832         www.allrecipes.com/recipe/8228/basque-cake/
# 6835   www.allrecipes.com/recipe/109917/austrian-tea-...
# 6850   www.allrecipes.com/recipe/21530/mini-cheesecak...
# 6871   www.allrecipes.com/recipe/8388/sour-cream-poun...
# 6885   www.allrecipes.com/recipe/34021/fluffy-cake-do...
# 6887   www.allrecipes.com/recipe/237564/spam-a-liciou...
# 6897        www.allrecipes.com/recipe/7509/jamaica-cake/
# 6917   www.allrecipes.com/recipe/46386/guadalupe-rive...
# 6921   www.allrecipes.com/recipe/237710/amazing-choco...
# 6923   www.allrecipes.com/recipe/221435/pastel-gallet...
# 6949   www.allrecipes.com/recipe/246722/old-fashioned...
# 6951   www.allrecipes.com/recipe/254793/pumpkin-pie-n...
# 6955   www.allrecipes.com/recipe/264876/strawberry-cr...
# 6985   www.allrecipes.com/recipe/231254/allies-awesom...
# 6997   www.allrecipes.com/recipe/262500/easy-lemon-cu...
# 7004   www.allrecipes.com/recipe/220934/italian-easte...
# 7010   www.allrecipes.com/recipe/265561/how-to-decora...
# 7014   www.allrecipes.com/recipe/14836/southwest-appe...
# 7031   www.allrecipes.com/recipe/17650/chewy-butter-c...
# 7055   www.allrecipes.com/recipe/266545/chocolate-str...
# 7056   www.allrecipes.com/recipe/59804/cherry-fruitca...
# 7103   www.allrecipes.com/recipe/236915/lemon-butterm...
# 7106   www.allrecipes.com/recipe/154144/simple-and-de...
# 7110   www.allrecipes.com/recipe/260484/pancake-muffi...
# 7142   www.allrecipes.com/recipe/268398/kransekake-no...
# 7152   www.allrecipes.com/recipe/255416/okonomiyaki-j...
# 7156   www.allrecipes.com/recipe/154886/pancake-and-s...
# 7157   www.allrecipes.com/recipe/235906/ritz-new-york...
# 7161    www.allrecipes.com/recipe/10523/coriander-cakes/
# 7165   www.allrecipes.com/recipe/26003/simple-chocola...
# 7169   www.allrecipes.com/recipe/33118/german-potato-...
# 7173   www.allrecipes.com/recipe/23422/black-chocolat...
# 7221   www.allrecipes.com/recipe/228345/michigan-mapl...
# 7234   www.allrecipes.com/recipe/259056/brookie-panca...
# 7236   www.allrecipes.com/recipe/238756/lemon-frosted...
# 7241   www.allrecipes.com/recipe/9834/light-and-chewy...
# 7262   www.allrecipes.com/recipe/8001/oooh-baby-choco...
# 7269   www.allrecipes.com/recipe/72982/gluten-free-or...
# 7278   www.allrecipes.com/recipe/21540/blueberry-pota...
# 7287   www.allrecipes.com/recipe/26016/cranberry-upsi...
# 7311   www.allrecipes.com/recipe/246585/carrot-cake-c...
# 7322   www.allrecipes.com/recipe/218001/strawberry-sh...
# 7323   www.allrecipes.com/recipe/100373/chocolate-pop...
# 7369   www.allrecipes.com/recipe/238965/margaretas-ca...
# 7382   www.allrecipes.com/recipe/7665/lemon-pudding-c...
# 7397   www.allrecipes.com/recipe/240279/applesauce-fi...
# 7403   www.allrecipes.com/recipe/7883/banana-pudding-...
# 7412   www.allrecipes.com/recipe/206817/delicious-stu...
# 7432   www.allrecipes.com/recipe/17823/polish-style-c...
# 7445   www.allrecipes.com/recipe/230287/pumpkin-pecan...
# 7446   www.allrecipes.com/recipe/7768/butterscotch-ca...
# 7491   www.allrecipes.com/recipe/260684/best-lemon-sh...
# 7505   www.allrecipes.com/recipe/236380/greek-yogurt-...
# 7520      www.allrecipes.com/recipe/22985/cornmeal-cake/
# 7527   www.allrecipes.com/recipe/206740/beghrir-moroc...
# 7530   www.allrecipes.com/recipe/246493/gluten-free-n...
# 7535    www.allrecipes.com/recipe/7282/pecan-pound-cake/
# 7589   www.allrecipes.com/recipe/235073/toasted-marsh...
# 7594    www.allrecipes.com/recipe/7847/lemonade-cake-ii/
# 7636   www.allrecipes.com/recipe/257209/super-moist-r...
# 7645   www.allrecipes.com/recipe/260285/halloween-gra...
# 7647   www.allrecipes.com/recipe/16266/cranberry-pear...
# 7664   www.allrecipes.com/recipe/221015/carrot-cake-o...
# 7668   www.allrecipes.com/recipe/256226/colleens-glut...
# 7684   www.allrecipes.com/recipe/259611/snickers-chee...
# 7701   www.allrecipes.com/recipe/244984/cara-cara-cup...
# 7715   www.allrecipes.com/recipe/8345/caramel-nougat-...
# 7726   www.allrecipes.com/recipe/9266/christmas-cherr...
# 7735   www.allrecipes.com/recipe/258845/gramma-durbin...
# 7755       www.allrecipes.com/recipe/7562/cone-cupcakes/
# 7758   www.allrecipes.com/recipe/223016/fresh-blueber...
# 7794   www.allrecipes.com/recipe/26013/coconut-chocol...
# 7855   www.allrecipes.com/recipe/8278/champagne-cake-...
# 7873   www.allrecipes.com/recipe/259994/ghirardelli-m...
# 7883   www.allrecipes.com/recipe/262507/key-lime-coco...
# 7896   www.allrecipes.com/recipe/234702/quick-almond-...
# 7899   www.allrecipes.com/recipe/219859/gluten-free-s...
# 7901       www.allrecipes.com/recipe/25573/dr-bird-cake/
# 7906   www.allrecipes.com/recipe/26001/chocolate-shee...
# 7912   www.allrecipes.com/recipe/260555/favorite-butt...
# 7936   www.allrecipes.com/recipe/230202/homemade-panc...
# 7950   www.allrecipes.com/recipe/244364/amazingly-eas...
# 7951   www.allrecipes.com/recipe/260549/raundis-swedi...
# 7986    www.allrecipes.com/recipe/233433/shark-cupcakes/
# 8004   www.allrecipes.com/recipe/100827/baked-chocola...
# 8028   www.allrecipes.com/recipe/7585/toffee-bar-coff...
# 8031   www.allrecipes.com/recipe/233496/sweet-potato-...
# 8039   www.allrecipes.com/recipe/255033/zucchini-kuch...
# 8041   www.allrecipes.com/recipe/26007/cinnamon-coffe...
# 8054   www.allrecipes.com/recipe/15857/easy-pineapple...
# 8077   www.allrecipes.com/recipe/260564/mini-pecan-pi...
# 8123   www.allrecipes.com/recipe/262720/strawberry-ch...
# 8137   www.allrecipes.com/recipe/232829/easy-rice-flo...
# 8151   www.allrecipes.com/recipe/17172/no-bake-chocol...
# 8158   www.allrecipes.com/recipe/35448/apple-cinnamon...
# 8161      www.allrecipes.com/recipe/16317/oatmeal-cakes/
# 8175   www.allrecipes.com/recipe/268225/brown-butter-...
# 8190   www.allrecipes.com/recipe/241687/fine-crisp-ca...
# 8208      www.allrecipes.com/recipe/7527/easy-dump-cake/
# 8212   www.allrecipes.com/recipe/7704/cherry-cream-ch...
# 8251       www.allrecipes.com/recipe/35530/beetnik-cake/
# 8252   www.allrecipes.com/recipe/255957/glazed-apple-...
# 8253   www.allrecipes.com/recipe/232805/racuchy-z-jab...
# 8270   www.allrecipes.com/recipe/34832/spinach-pancakes/
# 8281   www.allrecipes.com/recipe/235771/orange-spice-...
# 8289   www.allrecipes.com/recipe/22953/dark-chocolate...
# 8315   www.allrecipes.com/recipe/89351/jackies-fruitc...
# 8323   www.allrecipes.com/recipe/256404/almond-crunch...
# 8338   www.allrecipes.com/recipe/241743/coconut-flan-...
# 8342   www.allrecipes.com/recipe/7550/pineapple-cake-ii/
# 8344   www.allrecipes.com/recipe/216555/upside-down-p...
# 8357   www.allrecipes.com/recipe/25637/strawberry-dre...
# 8379   www.allrecipes.com/recipe/8067/vanilla-wafer-c...
# 8384   www.allrecipes.com/recipe/262704/bacon-potato-...
# 8429   www.allrecipes.com/recipe/17574/nells-irish-bo...
# 8464   www.allrecipes.com/recipe/24509/grandmas-famou...
# 8471   www.allrecipes.com/recipe/216901/bacon-cheddar...
# 8498   www.allrecipes.com/recipe/8060/passover-sponge...
# 8519   www.allrecipes.com/recipe/213685/passover-lemo...
# 8531       www.allrecipes.com/recipe/7378/sunshine-cake/
# 8538   www.allrecipes.com/recipe/247061/coconut-minis...
# 8545   www.allrecipes.com/recipe/7687/coconut-layer-c...
# 8555   www.allrecipes.com/recipe/264550/sweet-or-savo...
# 8594   www.allrecipes.com/recipe/256530/strawberry-ch...
# 8605   www.allrecipes.com/recipe/245037/chocolate-pum...
# 8610          www.allrecipes.com/recipe/92959/pup-cakes/
# 8613   www.allrecipes.com/recipe/270367/apple-pie-che...
# 8617   www.allrecipes.com/recipe/19836/lemon-cooler-c...
# 8628   www.allrecipes.com/recipe/17468/mary-annes-car...
# 8639   www.allrecipes.com/recipe/71888/sara-janes-oat...
# 8644   www.allrecipes.com/recipe/218217/almond-cupcak...
# 8681   www.allrecipes.com/recipe/184599/spiced-apple-...
# 8731     www.allrecipes.com/recipe/27028/irish-tea-cake/
# 8750   www.allrecipes.com/recipe/232898/double-chocol...
# 8763   www.allrecipes.com/recipe/94068/brownie-chocol...
# 8765   www.allrecipes.com/recipe/17995/dark-chocolate...
# 8775      www.allrecipes.com/recipe/19080/soda-pop-cake/
# 8788   www.allrecipes.com/recipe/203314/cinnamon-peac...
# 8805   www.allrecipes.com/recipe/258852/very-chocolat...
# 8846   www.allrecipes.com/recipe/7720/rum-and-raisin-...
# 8855   www.allrecipes.com/recipe/8288/chocolate-chip-...
# 8870   www.allrecipes.com/recipe/232177/cornbread-cakes/
# 8873   www.allrecipes.com/recipe/7994/coconut-poke-cake/
# 8898      www.allrecipes.com/recipe/25603/mars-bar-cake/
# 8909   www.allrecipes.com/recipe/228835/fresh-strawbe...
# 8963   www.allrecipes.com/recipe/264322/apple-pie-cup...
# 8976   www.allrecipes.com/recipe/194346/philadelphia-...
# 8979   www.allrecipes.com/recipe/7290/miss-beths-yogh...
# 8981   www.allrecipes.com/recipe/270366/strawberry-sh...
# 8982            www.allrecipes.com/recipe/7602/sad-cake/
# 8998   www.allrecipes.com/recipe/77832/cranberry-peca...
# 9066   www.allrecipes.com/recipe/8231/traditional-cof...
# 9084   www.allrecipes.com/recipe/256738/low-carb-panc...
# 9085   www.allrecipes.com/recipe/25572/double-chocola...
# 9126   www.allrecipes.com/recipe/86888/maryanns-upsid...
# 9155   www.allrecipes.com/recipe/239744/jds-apple-pie...
# 9173   www.allrecipes.com/recipe/17564/white-chocolat...
# 9183   www.allrecipes.com/recipe/19734/passover-apple...
# 9192   www.allrecipes.com/recipe/169652/chunky-monkey...
# 9201   www.allrecipes.com/recipe/7261/texas-sheet-cak...
# 9221   www.allrecipes.com/recipe/228315/banana-peanut...
# 9239   www.allrecipes.com/recipe/247102/sencha-green-...
# 9242   www.allrecipes.com/recipe/7279/pecan-sour-crea...
# 9254   www.allrecipes.com/recipe/258708/raspberry-lem...
# 9269   www.allrecipes.com/recipe/237429/pineapple-coc...
# 9281   www.allrecipes.com/recipe/17687/beat-and-bake-...
# 9292   www.allrecipes.com/recipe/257279/ultimate-butt...
# 9294   www.allrecipes.com/recipe/14055/golden-rice-ca...
# 9320   www.allrecipes.com/recipe/7180/sourdough-panca...
# 9321   www.allrecipes.com/recipe/260553/cornmeal-grid...
# 9362   www.allrecipes.com/recipe/260486/gluten-free-b...
# 9372   www.allrecipes.com/recipe/7401/rich-dark-fruit...
# 9377   www.allrecipes.com/recipe/7928/ugly-duckling-c...
# 9395   www.allrecipes.com/recipe/11421/crescent-cake-...
# 9415   www.allrecipes.com/recipe/236761/pecan-cajun-c...
# 9432           www.allrecipes.com/recipe/16058/jam-cake/
# 9465         www.allrecipes.com/recipe/7893/dundee-cake/
# 9512   www.allrecipes.com/recipe/26060/pumpkin-dump-c...
# 9514   www.allrecipes.com/recipe/221146/too-cool-for-...
# 9515   www.allrecipes.com/recipe/258166/the-best-vani...
# 9530   www.allrecipes.com/recipe/266547/fig-hazelnut-...
# 9533   www.allrecipes.com/recipe/267707/delicious-cak...
# 9545   www.allrecipes.com/recipe/254467/whips-fruit-s...
# 9549   www.allrecipes.com/recipe/16272/fresh-coconut-...
# 9580   www.allrecipes.com/recipe/254245/berries-and-c...
# 9584   www.allrecipes.com/recipe/17697/quick-chocolat...
# 9588   www.allrecipes.com/recipe/15432/angel-food-cak...
# 9607     www.allrecipes.com/recipe/11036/sweet-oatcakes/
# 9652   www.allrecipes.com/recipe/254222/homemade-boys...
# 9656   www.allrecipes.com/recipe/232966/chocolate-bun...
# 9668   www.allrecipes.com/recipe/24136/bobs-cinnamon-...
# 9682   www.allrecipes.com/recipe/237128/good-bad-and-...
# 9683   www.allrecipes.com/recipe/244676/two-ingredien...
# 9720   www.allrecipes.com/recipe/8376/chocolate-pound...
# 9768   www.allrecipes.com/recipe/8331/carrot-cake-wit...
# 9770   www.allrecipes.com/recipe/7493/buttermilk-poun...
# 9773   www.allrecipes.com/recipe/261888/rainbow-vanil...
# 9797   www.allrecipes.com/recipe/256558/hummingbird-c...
# 9804   www.allrecipes.com/recipe/8247/caramel-apple-c...
# 9823   www.allrecipes.com/recipe/245897/savory-pancak...
# 9861   www.allrecipes.com/recipe/240601/real-pistachi...
# 9879   www.allrecipes.com/recipe/263963/souffle-pancake/
# 9904   www.allrecipes.com/recipe/36018/kats-cheesecak...
# 9927   www.allrecipes.com/recipe/77782/warm-flourless...
# 9928   www.allrecipes.com/recipe/259247/no-bake-chees...
# 9948   www.allrecipes.com/recipe/256088/white-cake-wi...
# 9972   www.allrecipes.com/recipe/23046/marbled-pumpki...
# 9981   www.allrecipes.com/recipe/27185/cranberry-ice-...
# 9986   www.allrecipes.com/recipe/255353/paleo-carrot-...
# 9992    www.allrecipes.com/recipe/231278/baked-pancakes/
# 9996   www.allrecipes.com/recipe/26050/pink-azalea-cake/
# 10068  www.allrecipes.com/recipe/17829/chocolate-haze...
# 10070  www.allrecipes.com/recipe/8239/good-for-you-ch...
# 10077          www.allrecipes.com/recipe/22918/pop-cake/
# 10082  www.allrecipes.com/recipe/220707/jelly-doughnu...
# 10106  www.allrecipes.com/recipe/245407/mint-chocolat...
# 10109  www.allrecipes.com/recipe/260788/mexican-hot-c...
# 10117  www.allrecipes.com/recipe/21581/aunt-ts-dwi-ru...
# 10176  www.allrecipes.com/recipe/230058/salted-carame...
# 10187  www.allrecipes.com/recipe/7949/lemon-cake-with...
# 10217  www.allrecipes.com/recipe/232161/banana-bundt-...
# 10240  www.allrecipes.com/recipe/157201/vanilla-bean-...
# 10258  www.allrecipes.com/recipe/7943/valeries-cherry...
# 10275  www.allrecipes.com/recipe/8447/chocolate-hazel...
# 10283  www.allrecipes.com/recipe/231561/mama-gunns-po...
# 10286        www.allrecipes.com/recipe/8042/sleepy-cake/
# 10294  www.allrecipes.com/recipe/244992/white-chocola...
# 10329  www.allrecipes.com/recipe/231892/idahoan-coca-...
# 10347   www.allrecipes.com/recipe/7481/miami-beach-cake/
# 10352  www.allrecipes.com/recipe/246898/chocolate-pea...
# 10370  www.allrecipes.com/recipe/258174/healthy-ginge...
# 10375  www.allrecipes.com/recipe/232371/lemon-coconut...
# 10380    www.allrecipes.com/recipe/221147/grad-cupcakes/
# 10383  www.allrecipes.com/recipe/267568/sweet-potato-...
# 10385  www.allrecipes.com/recipe/260623/chocolate-cak...
# 10396  www.allrecipes.com/recipe/258164/the-cheesecak...
# 10405    www.allrecipes.com/recipe/17133/pink-lady-cake/
# 10412  www.allrecipes.com/recipe/258319/black-forest-...
# 10414  www.allrecipes.com/recipe/241517/banana-chiffo...
# 10416  www.allrecipes.com/recipe/265401/strawberry-sh...
# 10448  www.allrecipes.com/recipe/8284/pineapple-lemon...
# 10454  www.allrecipes.com/recipe/75391/russian-pancak...
# 10462  www.allrecipes.com/recipe/269697/onion-shortcake/
# 10472  www.allrecipes.com/recipe/69384/soy-milk-panca...
# 10489  www.allrecipes.com/recipe/220706/fruity-mini-c...
# 10493  www.allrecipes.com/recipe/256135/have-mercy-tr...
# 10507  www.allrecipes.com/recipe/269511/eggless-orang...
# 10511  www.allrecipes.com/recipe/230140/coconut-sour-...
# 10531  www.allrecipes.com/recipe/17775/chocolate-pudd...
# 10542  www.allrecipes.com/recipe/218605/savory-blue-c...
# 10575  www.allrecipes.com/recipe/24985/red-velvet-cak...
# 10604  www.allrecipes.com/recipe/19103/swiss-white-ch...
# 10619  www.allrecipes.com/recipe/228517/creme-brulee-...
# 10628  www.allrecipes.com/recipe/26235/strawberry-cak...
# 10639    www.allrecipes.com/recipe/17344/carrot-cake-xi/
# 10647  www.allrecipes.com/recipe/260479/traditional-c...
# 10652  www.allrecipes.com/recipe/7398/orange-delight-...
# 10662  www.allrecipes.com/recipe/259295/apple-coffee-...
# 10694  www.allrecipes.com/recipe/218632/incredible-ra...
# 10700  www.allrecipes.com/recipe/7485/bee-sting-cake-...
# 10706  www.allrecipes.com/recipe/8457/sweet-potato-po...
# 10711  www.allrecipes.com/recipe/220615/apple-potato-...
# 10715  www.allrecipes.com/recipe/7314/favorite-chocol...
# 10732  www.allrecipes.com/recipe/237439/sopapilla-cup...
# 10757  www.allrecipes.com/recipe/262175/russian-sour-...
# 10768  www.allrecipes.com/recipe/223200/cranberry-pec...
# 10785  www.allrecipes.com/recipe/155084/banana-and-va...
# 10798  www.allrecipes.com/recipe/231279/coconut-banan...
# 10810  www.allrecipes.com/recipe/257489/texas-chocola...
# 10837  www.allrecipes.com/recipe/7831/amish-friendshi...
# 10846       www.allrecipes.com/recipe/7370/crumb-cake-i/
# 10898  www.allrecipes.com/recipe/236258/jeweled-panca...
# 10932  www.allrecipes.com/recipe/240655/cake-vodka-ba...
# 10933  www.allrecipes.com/recipe/245404/chocolate-cle...
# 10939  www.allrecipes.com/recipe/215273/nairobi-choco...
# 10960  www.allrecipes.com/recipe/244964/simple-cake-p...
# 10974          www.allrecipes.com/recipe/8023/pour-cake/
# 10979  www.allrecipes.com/recipe/263958/keto-diet-low...
# 10999  www.allrecipes.com/recipe/258388/kasutera-cast...
# 11015   www.allrecipes.com/recipe/244965/easy-cake-pops/
# 11018  www.allrecipes.com/recipe/23357/cinnamon-panca...
# 11020  www.allrecipes.com/recipe/259703/pumpkin-chees...
# 11030  www.allrecipes.com/recipe/27511/giant-ding-don...
# 11033  www.allrecipes.com/recipe/245740/vegan-devils-...
# 11038      www.allrecipes.com/recipe/7766/amaretto-cake/
# 11043  www.allrecipes.com/recipe/17112/cake-mix-cooki...
# 11048  www.allrecipes.com/recipe/15405/carrot-pineapp...
# 11074  www.allrecipes.com/recipe/230649/5-minute-micr...
# 11145  www.allrecipes.com/recipe/240082/easy-german-c...
# 11146  www.allrecipes.com/recipe/259052/snickerdoodle...
# 11165  www.allrecipes.com/recipe/7654/almond-lemon-cake/
# 11172  www.allrecipes.com/recipe/18037/throw-it-toget...
# 11194  www.allrecipes.com/recipe/143336/frozen-raspbe...
# 11196  www.allrecipes.com/recipe/239967/whole-wheat-c...
# 11199  www.allrecipes.com/recipe/138932/sour-cream-cu...
# 11200  www.allrecipes.com/recipe/7751/angel-food-cake...
# 11204  www.allrecipes.com/recipe/19086/strawberry-cak...
# 11244  www.allrecipes.com/recipe/7956/dark-chocolate-...
# 11250  www.allrecipes.com/recipe/237990/chocolate-chi...
# ...
# 38298  eggs garlic green onions ground black pepper I...
# 38307  all-purpose butter butter cornstarch cream che...
# 38320  butter chocolate chips coffee granules egg whi...
# 38324  bacon baking powder chunky peanut butter eggs ...
# 38326  egg yolks heavy whipping cream milk vanilla wh...
# 38335  almond baking powder cake flour egg whites mil...
# 38419  butter cake mix chocolate chips condensed milk...
# 38420  all-purpose butter eggs lemon lemon juice milk...
# 38452  black licorice laces cupcakes eyeballs marshma...
# 38463  baking powder boiling water brown sugar eggs f...
# 38508  almond extract baking powder canola oil eggs s...
# 38520  baking powder eggs flour ground nutmeg olive o...
# 38546  all-purpose almonds apricot preserves candied ...
# 38550  canola oil cooking spray eggs pumpkin pumpkin ...
# 38556  baking powder butter eggs flour milk salt vani...
# 38572  baking soda cocoa flour salt vanilla vegetable...
# 38583  apples brown sugar butter buttermilk baking eg...
# 38596  baking powder cake flour cream of tartar egg w...
# 38600  baking powder baking soda banana buttermilk eg...
# 38603  frozen whipped topping milk orange cake orange...
# 38614  all-purpose baking powder butter eggs milk sal...
# 38628  baking powder chocolate chips cocoa creme frai...
# 38632   apple cider apples pancake mix water white sugar
# 38654  baking powder baking soda eggs ground cinnamon...
# 38658  baking soda butter coconut oil egg flour salt ...
# 38659  brownie mix butter chocolate frosting condense...
# 38660  almond baking soda butter buttermilk eggs flou...
# 38663  cornstarch cream cheese dish pie crust eggs fr...
# 38682  baking soda butter confectioners cream egg flo...
# 38698  brown sugar butter butterscotch chips eggs str...
# 38711  brown sugar cream of tartar eggs flour ground ...
# 38712  brownie mix caramels chocolate fudge topping c...
# 38718  baking powder butter chocolate-hazelnut chocol...
# 38720  all-purpose butter Colby cheese cream cheese e...
# 38725  active dry yeast butter butter butter cinnamon...
# 38727  all-purpose baking soda cocoa mayonnaise vanil...
# 38746  brown sugar clove garlic Dipping Sauce eggs fl...
# 38756  baking powder banana coconut milk egg flax see...
# 38775  all-purpose baking powder eggs lemon juice mar...
# 38786  all-purpose baking powder baking soda butter c...
# 38813  cream cheese eggs vanilla vanilla wafers white...
# 38827  baking powder butter butter chocolate sprinkle...
# 38835  baking soda brown sugar Carrot carrots Cream C...
# 38847  boiling water canola oil canola oil flour gree...
# 38857  baking powder baking soda Chocolate Cupcakes c...
# 38871  cake mix chocolate chips chocolate pudding cof...
# 38874  almond milk applesauce baking soda coconut flo...
# 38878  baking powder baking soda cake flour chocolate...
# 38896  bread crumbs butter garlic salt green bell pep...
# 38899  baking powder baking soda brown rice flour cor...
# 38916  baking powder coconut oil coconut oil cooking ...
# 38940  all-purpose baking powder butter cocoa eggs le...
# 38950  baking powder baking soda butter eggs flour gr...
# 38952  butter confectioners cream cheese eggs flour l...
# 38962  baking powder baking soda butter cooking spray...
# 38972  butter caramels condensed milk cookie crumbs c...
# 38989  baking soda butter buttermilk cocoa eggs flour...
# 39002  almond cream cheese fresh strawberries milk yo...
# 39016  baking powder baking soda brown sugar butter c...
# 39018  almond extract baking powder cornstarch drops ...
# 39063  chocolate chocolate chips eggs vanilla pudding...
# 39064  baking soda banana bananas butter butter butte...
# 39074  butter cornstarch egg fresh berries regular cr...
# 39077  baking powder egg flour milk old-fashioned oat...
# 39088  baking mix baking mix boysenberries brown suga...
# 39099  baking mix chicken stock eggs garlic onion Par...
# 39104  almond paste apricots baking powder bitterswee...
# 39124      butter walnuts whiskey white cake white sugar
# 39132  apple baking soda brown sugar butter cranberri...
# 39162  almond baking powder baking soda butter butter...
# 39171  chocolate sandwich cookies chocolate sandwich ...
# 39226  all-purpose candied cherries condensed milk da...
# 39228  almond almond extract almonds baking powder ch...
# 39234  butter cream cheese eggs peppermint Scout Scou...
# 39242  bread crumbs cold mashed potatoes dill weed eg...
# 39255  cream cheese egg whites frozen margarita lime ...
# 39276  cold water egg whites ground cinnamon ground c...
# 39310  baking soda butter egg flour heavy cream honey...
# 39342  all-purpose almonds baking soda cinnamon cranb...
# 39354  eggs orange juice sugar vegetable oil vegetabl...
# 39360  brown sugar butter chocolate chips cream chees...
# 39396  baking powder baking soda butter carrots Cream...
# 39411  butter carrot cake carrots cream cheese frosti...
# 39419  baking powder eggs flour milk shortening vanil...
# 39426  almond flour applesauce baking soda coconut oi...
# 39429  bacon butter eggs Gouda cheese ground black pe...
# 39435  eggs ground nutmeg sherry sugar vegetable oil ...
# 39437                      blackberries cornstarch sugar
# 39479  baking powder chickpeas chocolate chips coconu...
# 39485  baking soda banana brown sugar cooking oats fl...
# 39496  cherry pie filling cherry-flavored cola chocol...
# 39509  baking soda butter butter cake eggs lemon juic...
# 39511  butter butter condensed milk cooking spray cre...
# 39559  baking powder coffee granules eggs flour powde...
# 39563  chocolate-hazelnut spread cream cheese graham ...
# 39569  bittersweet chocolate butter cake flour eggs w...
# 39614  cake mix egg whites graham cracker crumbs grah...
# 39644  butter cream cheese eggs Frosting frozen whipp...
# 39680         butter cream cheese eggs sugar yellow cake
# 39690  clear imitation powdered butter salt shortenin...
# 39697  all-purpose apple apples brown sugar brown sug...
# 39721  butter egg yolks flaked coconut milk nuts vani...
# 39730  cream cheese egg whites Filling graham cracker...
# 39740  baking powder baking soda butter cream cheese ...
# 39744  all-purpose baking soda butter eggs ground nut...
# 39766  baking soda butter chocolate eggs flour milk s...
# 39780  butter chocolate wafer cookies coloring cornst...
# 39803     baking powder eggs flour milk salt white sugar
# 39808  eggs frozen whipped topping mandarin oranges p...
# 39828  all-purpose apples baking soda brown sugar but...
# 39836  chocolate cake container coconut pecan frostin...
# 39842  baking soda butter coconut eggs graham cracker...
# 39860  baking powder butter butter buttermilk butterm...
# 39872  all-purpose apples baking powder brown sugar e...
# 39877  butter cherry pie filling crackers cream chees...
# 39893  almonds baking powder baking soda flour flour ...
# 39902  all-purpose almond flour boiling water boiling...
# 39944  baking powder blueberries brown sugar butter e...
# 39949  almond angel food cake cherry pie filling froz...
# 39953  baking powder baking soda butter cinnamon suga...
# 39967  butter cold water eggnog eggnog eggs Filling g...
# 39978  angel food cake bananas frozen whipped topping...
# 39983  chocolate chip cake eggs raisins rolled oats s...
# 39993  baking powder cold water eggs flour green tea ...
# 40009  baking powder baking soda brown sugar brown su...
# 40018  butter chocolate cocoa cocoa coffee coffee cof...
# 40067  dates graham cracker crumbs marshmallows milk ...
# 40068  baking soda butter cocoa eggs flour milk salt ...
# 40080  baking powder cake flour egg yolks milk salt u...
# 40114  baking soda brandy brown sugar butter candied ...
# 40151  bittersweet chocolate cocoa egg whites egg yol...
# 40153  baking powder baking soda butter canola oil cr...
# 40160           butter milk milk chocolate sugar vanilla
# 40177  all-purpose baking powder baking soda boiling ...
# 40189  coconut eggs flaked coconut flaked coconut fro...
# 40193  margarine rhubarb strawberry flavored water wh...
# 40203  cake flour cream of tartar egg whites salt sug...
# 40227  all-purpose almond flour baking powder baking ...
# 40232  baking powder butter butter cocoa cocoa eggs f...
# 40249  baking powder butter cake flour eggs milk salt...
# 40265  all-purpose baking soda brown sugar eggs groun...
# 40331  all-purpose baking soda brown sugar cold coffe...
# 40340  cooking spray crispy rice cereal egg golden bu...
# 40350  chickpeas chili powder egg garlic ground coria...
# 40351  baking powder baking soda buttermilk cranberry...
# 40367  coloring coloring coloring milk multi-colored ...
# 40369  baking soda cherry pie filling chocolate chips...
# 40378  butter cherry pie filling cream cheese eggs gr...
# 40404                     chocolate cake chocolate chips
# 40424  baking soda butter chocolate chips cocoa eggs ...
# 40480  baking powder baking soda black decorating But...
# 40481  baking soda chocolate cocoa eggs flour hot wat...
# 40483  baking soda butter chocolate cocoa cookies egg...
# 40497  fish sauce fresh breadcrumbs fresh cilantro fr...
# 40517  baking powder cherries eggs flour flour ground...
# 40518  baking powder brown sugar cornstarch eggs flou...
# 40521  blueberries cream cheese frosting eggs muffin ...
# 40537  bottomed ice cream cones semi-sweet chocolate ...
# 40575       cottage cheese egg whites oats spray vanilla
# 40607                 chocolate cake chocolate ice cream
# 40612             cheesecloth fruitcake grapefruit juice
# 40618  all-purpose baking powder buckwheat flour cook...
# 40636  butter cream cheese graham cracker crumbs heav...
# 40642  butter butter cocoa dark chocolate egg yolks e...
# 40670  bananas cream frozen whipped topping milk pine...
# 40690  baking powder baking soda cocoa eggs flour sal...
# 40703  all-purpose baking soda cherries cocoa cornsta...
# 40704  baking powder baking soda butter eggs flour mi...
# 40713  butter chocolate pudding cream cheese flour fr...
# 40719  cake flour cream of tartar egg whites honey sa...
# 40738  all-purpose almond baking soda butter eggs pea...
# 40755  baking powder baking soda butter chocolate chi...
# 40757  flaked coconut jellybeans red licorice vanilla...
# 40763  baking powder butter egg flour fresh rhubarb m...
# 40777  almond flour baking powder banana brown rice f...
# 40781  baking powder cake flour egg yolk milk salt sh...
# 40786  granular no milk nonfat plain yogurt shortbrea...
# 40796  brown sugar brown sugar cookie crumbs cream ch...
# 40848  baking powder brown sugar egg flour milk olive...
# 40852  cream eggs flour Lemon Cream Icing lemon juice...
# 40861  eggs fresh blueberries lemon cake lemon zest o...
# 40865  almond milk arrowroot flour baking powder baki...
# 40874  almond egg whites flour salt sour cream vanill...
# 40882  baking powder cake flour chocolate confectione...
# 40890  brown sugar brown sugar cream cheese cream che...
# 40903  baking soda butter butter cream cheese Cream C...
# 40910  baking powder baking soda brown sugar butter b...
# 40912  cherry flavored chocolate cake eggs rhubarb ve...
# 40941   cream cheese flour tortilla strawberry jam sugar
# 40970  baking powder black plums blueberries brown su...
# 40989  baking powder baking soda brown sugar brown su...
# 41018  anchovies cakes chile paste corn syrup onion s...
# 41023  all-purpose butter eggs frozen strawberries st...
# 41027           butter eggs flour milk water white sugar
# 41040  almond extract baking powder batter brown suga...
# 41051  cherry pie filling graham cracker crust plain ...
# 41127                                        bread cakes
# 41620                                     Cupcake yogurt
# 41724                                     pineapple cake
# 41786                                     Cupcake Batter
# 42319                                           cupcakes
# 42417                           complete dry pancake mix
# 42419                                            Cupcake
# 42839                                 buttermilk pancake
# 42856                                leftover bunny cake
# 42896                                      Pancake syrup
# 43008                               chocolate fudge cake
# 43236                                       natural cake
# 43275                                   gingerbread cake
# 43382                                        orange cake
# 43529                                           cake mix
# 43622                                               Cake
# 43684                                          cake pans
# 43811                                cake-flavored vodka
# 43911                                     white cake mix
# 43963                                              cakes
# 43983                                   fruitcake crumbs
# 43994                          vanilla flavored cake mix
# 44044                                 Chocolate Cupcakes
# 44079                                 chocolate cake mix
# 44368                                golden vanilla cake
# 44400                                red velvet cake mix
# 44411                                   cakes cake yeast
# 44579                                         white cake
# 44697                                        butter cake
# 45035                                        cake donuts
# 45104                                        yellow cake
# 45123                                        banana cake
# 45371                                 pancake/waffle mix
# 45436                                     chocolate cake
# 45445                                         shortcakes
# 45502                                    frozen pancakes
# 45619                                         rice cakes
# 45673                                          fruitcake
# 46115                              strawberry-lemon cake
# 46180                              chocolate cake crumbs
# 46465                                         matzo cake
# 46868                                        sponge cake
# 46956                                         cake flour
# 47315                                chocolate chip cake
# 47409                                      pancake syrup
# 47755                                        carrot cake
# 47883                                  white cake layers
# 47909                                    angel food cake
# 48026                                         lemon cake
# 48037                                            pancake
# 48264                    cream-filled sponge snack cakes
# 48500                                               cake
# 48568                                   Coconut Cupcakes
# 48747                                         cake spice
# 48838                               Swiss chocolate cake
# 48953                                    matzo cake meal
# 48956                                        cherry cake
# 49023                                       vanilla cake
# 49070                                     cupcake liners
# 49077                                        pancake mix
# 49328                  Korean-style glutinous rice cakes
# 49348                                          rice cake
# 49531                                  fluid ounces cake
# 49538                                  frozen pound cake
# 49552                                    strawberry cake
# 49815                                               CAKE
# 49855                                    red velvet cake
# 49954                                   matzo cake flour
# 50223                                        Almond Cake
# 50307                                   cherry chip cake
# 50313                                       almond cakes
# 50434                                        cake shells
# 50655                            whole wheat pancake mix
# 50813                                pancake/biscuit mix
# 50936                                      Chicken Cakes

# %%
nutrition_features = pd.DataFrame(
    list(
        data_w_nutrition.Nutrition_facts_unstructured.progress_apply(
            nutrition_facts_parser
        ).values
    )
)
# Out:
#   0%|          | 0/50980 [00:00<?, ?it/s]

# %%
data_w_nutrition.Nutrition_facts_unstructured.iloc[1]
# Out:
# 'Nutrition Facts\nServings Per Recipe 5\nCalories 209\n% Daily Value *\nTotal Fat 12g 15%\nSaturated Fat 2g 9%\nSodium 1mg 0%\nTotal Carbohydrate 25g 9%\nDietary Fiber 3g 10%\nTotal Sugars 10g\nProtein 2g\nCalcium 2mg 0%\nIron 1mg 3%\nPotassium 58mg 1%\n* Percent Daily Values are based on a 2,000 calorie diet. Your daily values may be higher or lower depending on your calorie needs.\n** Nutrient information is not available for all ingredients. Amount is based on available nutrient data.\n(-) Information is not currently available for this nutrient. If you are following a medically restrictive diet, please consult your doctor or registered dietitian before preparing this recipe for personal consumption.\nPowered by the ESHA Research Database © 2018, ESHA Research, Inc. All Rights Reserved'

# %% [markdown]
# ## Merging nutrition features to the recipes' metadata:

# %%
cols = ["title", "link", "sorted_NER"]
recipes_with_nutrition_features = data_w_nutrition[cols].join(
    nutrition_features
)
print(
    "recipe with link, ingredients and nutrition facts features: ",
    recipes_with_nutrition_features.shape,
)

recipes_with_nutrition_features.head()
# Out:
# recipe with link, ingredients and nutrition facts features:  (50980, 27)
#                                      title  \
# 0  Deconstructed Screwdriver (The Raw Egg)
# 1                              Kettle Corn
# 2                     Pop'S Fabulous Ajvar
# 3                 Chipotle-Mango Guacamole
# 4            Basic Homemade Ricotta Cheese
#
#                                                 link  \
# 0  www.allrecipes.com/recipe/241895/deconstructed...
# 1       www.allrecipes.com/recipe/20808/kettle-corn/
# 2  www.allrecipes.com/recipe/238733/pops-fabulous...
# 3  www.allrecipes.com/recipe/241254/chipotle-mang...
# 4  www.allrecipes.com/recipe/261696/basic-homemad...
#
#                                           sorted_NER  servings  calories  \
# 0                      [jiggers vodka, orange juice]       1.0     222.0
# 1      [popcorn kernels, vegetable oil, white sugar]       5.0     209.0
# 2  [cooking spray, corn oil, eggplants, garlic, g...      10.0     201.0
# 3  [avocados, black pepper, cayenne pepper, cilan...      20.0      77.0
# 4  [heavy whipping cream, milk, salt, white vinegar]       4.0     359.0
#
#    total_fat_g  total_fat_prct_daily  sodium_mg  sodium_prct_daily  \
# 0          0.0                   0.0        2.0                0.0
# 1         12.0                  15.0        1.0                0.0
# 2         17.0                  22.0       22.0                1.0
# 3          6.0                   8.0       15.0                1.0
# 4         25.0                  32.0      473.0               21.0
#
#    total_carbs_g  total_carbs_prct_daily  dietary_fiber_g  \
# 0            6.0                     2.0              0.0
# 1           25.0                     9.0              3.0
# 2           12.0                     4.0              6.0
# 3            6.0                     2.0              3.0
# 4           20.0                     7.0              NaN
#
#    dietary_fiber_prct_daily  total_sugars_g  protein_g  vitamin_c_mg  \
# 0                       0.0             5.0        0.0          31.0
# 1                      10.0            10.0        2.0           NaN
# 2                      20.0             6.0        2.0         105.0
# 3                      11.0             2.0        1.0           8.0
# 4                       NaN            19.0       14.0           0.0
#
#    vitamin_c_prct_daily  calcium_mg  calcium_prct_daily  iron_mg  \
# 0                 155.0         7.0                 1.0      0.0
# 1                   NaN         2.0                 0.0      1.0
# 2                 527.0        21.0                 2.0      1.0
# 3                  42.0        11.0                 1.0      0.0
# 4                   1.0       502.0                39.0      0.0
#
#    iron_prct_daily  potassium_mg  potassium_prct_daily  saturated_fat_g  \
# 0              1.0         125.0                   3.0              NaN
# 1              3.0          58.0                   1.0              2.0
# 2              4.0         457.0                  10.0              2.0
# 3              2.0         242.0                   5.0              1.0
# 4              1.0         633.0                  13.0             15.0
#
#    saturated_fat_prct_daily  cholesterol_mg  cholesterol_prct_daily
# 0                       NaN             NaN                     NaN
# 1                       9.0             NaN                     NaN
# 2                      11.0             NaN                     NaN
# 3                       6.0             1.0                     0.0
# 4                      74.0            84.0                    28.0

# %%
recipes_with_nutrition_features[nutrition_features.columns].describe().T
# Out:
#                             count        mean          std  min    25%    50%  \
# servings                  41073.0   11.271005    13.506715  1.0    4.0    8.0
# calories                  41075.0  323.305100   218.522628  0.0  170.0  286.0
# total_fat_g               40428.0   16.553329    14.944319  0.0    7.0   13.0
# total_fat_prct_daily      40428.0   21.162338    19.151932  0.0    8.0   17.0
# sodium_mg                 41046.0  559.104298  1674.329830  0.0  127.0  322.0
# sodium_prct_daily         41046.0   24.303927    72.798570  0.0    6.0   14.0
# total_carbs_g             41043.0   31.681334    25.185341  0.0   14.0   27.0
# total_carbs_prct_daily    41043.0   11.503740     9.163301  0.0    5.0   10.0
# dietary_fiber_g           39603.0    2.901422     3.121244  0.0    1.0    2.0
# dietary_fiber_prct_daily  39603.0   10.254122    11.063640  0.0    3.0    7.0
# total_sugars_g            40210.0   12.952524    16.360226  0.0    3.0    7.0
# protein_g                 40783.0   13.305127    14.568718  0.0    3.0    7.0
# vitamin_c_mg              36685.0   16.960829    29.260880  0.0    1.0    6.0
# vitamin_c_prct_daily      36685.0   84.925228   146.228214  0.0    7.0   31.0
# calcium_mg                41017.0   99.651072   120.772695  0.0   27.0   59.0
# calcium_prct_daily        41017.0    7.664261     9.299051  0.0    2.0    5.0
# iron_mg                   40376.0    2.272513     3.082488  0.0    1.0    2.0
# iron_prct_daily           40376.0   12.411408    16.984752  0.0    4.0    9.0
# potassium_mg              41045.0  367.346473   360.100340  0.0  107.0  261.0
# potassium_prct_daily      41045.0    7.811841     7.671995  0.0    2.0    6.0
# saturated_fat_g           39075.0    6.548279     6.666896  0.0    2.0    5.0
# saturated_fat_prct_daily  39075.0   32.768394    33.283144  0.0   10.0   23.0
# cholesterol_mg            33711.0   70.548782    78.239623  0.0   20.0   51.0
# cholesterol_prct_daily    33711.0   23.513927    26.082415  0.0    7.0   17.0
#
#                             75%       max
# servings                   12.0     472.0
# calories                  428.0    5974.0
# total_fat_g                23.0     492.0
# total_fat_prct_daily       29.0     630.0
# sodium_mg                 721.0  181849.0
# sodium_prct_daily          31.0    7906.0
# total_carbs_g              44.0     622.0
# total_carbs_prct_daily     16.0     226.0
# dietary_fiber_g             4.0      44.0
# dietary_fiber_prct_daily   14.0     159.0
# total_sugars_g             18.0     575.0
# protein_g                  21.0     460.0
# vitamin_c_mg               21.0    1347.0
# vitamin_c_prct_daily      105.0    6736.0
# calcium_mg                122.0    2183.0
# calcium_prct_daily          9.0     168.0
# iron_mg                     3.0     288.0
# iron_prct_daily            16.0    1600.0
# potassium_mg              516.0    6063.0
# potassium_prct_daily       11.0     129.0
# saturated_fat_g             9.0     287.0
# saturated_fat_prct_daily   45.0    1434.0
# cholesterol_mg             94.0    4033.0
# cholesterol_prct_daily     31.0    1344.0

# %%
recipes_with_nutrition_features.to_csv(
    "recipes_with_nutrition_features.csv", index=False
)

# %% [markdown]
# ## Recommend based on ingredients:

# %%
ingredients_df = pd.DataFrame(
    recipes_with_nutrition_features.query(" link.isnull() ")["title"]
).reset_index()
ingredients_df.columns = ["ingredient_index", "ingredient"]
ingredients_df.to_csv("../data/ingredient_indices.csv", index=False)

# %%
ingredients_df.query(" ingredient.str.lower().str.contains('broccoli') ")

# %%
red_tomato_index = (
    ingredients_df.query(" ingredient == 'red tomato' ")
    .ingredient_index.astype(str)
    .squeeze()
)
eggs_index = (
    ingredients_df.query(" ingredient == 'eggs' ")
    .ingredient_index.astype(str)
    .squeeze()
)
broccoli_index = (
    ingredients_df.query(" ingredient == 'broccoli' ")
    .ingredient_index.astype(str)
    .squeeze()
)

red_tomato_index, eggs_index, broccoli_index
# Out:
# ('43048', '46668', '46777')

# %%
list(recommendable_recipes_embeddings.keys())[-1]
# Out:
# '41079'

# %%
# filter out the indices of the ingredients:
all_ingredients_indices = ingredients_df.ingredient_index.astype(str).tolist()

# get the ingredients indices from query:
query_ingredient_indices = [red_tomato_index, eggs_index, broccoli_index]

recommendable_recipes_embeddings = {
    key: value
    for key, value in recipe_title_embeddings.items()
    if key not in all_ingredients_indices
}

corpus_embeddings = torch.stack(list(recommendable_recipes_embeddings.values()))
corpus_embeddings = util.normalize_embeddings(corpus_embeddings)
corpus_embeddings = torch.squeeze(corpus_embeddings, dim=1)


ingredients_embeddings = [
    recipe_title_embeddings[index].to(device)
    for index in query_ingredient_indices
]

query_embeddings = torch.stack(ingredients_embeddings)
query_embeddings_normalized = util.normalize_embeddings(query_embeddings)
query_combined_embedding = torch.mean(query_embeddings_normalized, dim=0)

hits = util.semantic_search(
    query_combined_embedding, corpus_embeddings, score_function=util.dot_score
)

hits
# Out:
# [[{'corpus_id': 29495, 'score': 114.66667938232422},
#   {'corpus_id': 21051, 'score': 111.99999237060547},
#   {'corpus_id': 39386, 'score': 108.66668701171875},
#   {'corpus_id': 19805, 'score': 108.00003051757812},
#   {'corpus_id': 2495, 'score': 108.00000762939453},
#   {'corpus_id': 16588, 'score': 106.66668701171875},
#   {'corpus_id': 33112, 'score': 105.33333587646484},
#   {'corpus_id': 5922, 'score': 104.0},
#   {'corpus_id': 31578, 'score': 104.0},
#   {'corpus_id': 14436, 'score': 103.3333511352539}]]

# %%
corpus_embeddings.shape, query_combined_embedding.shape
# Out:
# (torch.Size([41080, 384]), torch.Size([1, 384]))

# %%
with open('../data/recommendable_recipes_embeddings.pkl', "wb") as fOut:
    pickle.dump(recommendable_recipes_embeddings, fOut, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# data_w_nutrition.iloc[hits[0][1]["corpus_id"]].sorted_joined_NER

data_w_nutrition.iloc[21051].sorted_joined_NER
# Out:
# 'Barilla® broccoli rabe chicken sausage extra-virgin olive oil garlic Parmesan cheese Salt white wine'

# %%
data_w_nutrition.iloc[14436].sorted_joined_NER
# Out:
# 'Barilla® Jumbo Shells chicken stock chili powder cilantro fresco cheese ground coriander ground cumin lemon juice lime juice olive oil orange juice packets sazon seasoning with coriander paprika pork shoulder salt'
